# %%
# %load_ext autoreload
# %autoreload 2

# %%
## Imports

import sys
sys.path.append("..") # Adds the project root to the path

# %%
print("Hello Marie! I love you soo much <3")
# Out:
# Hello Marie! I love you soo much <3

# %%
print("This is an additional Cell")
# Out:
# This is an additional Cell
