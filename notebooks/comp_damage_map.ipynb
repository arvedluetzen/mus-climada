# %% [markdown]
# ### Comp_damage_map
#
# (percentage impact x percentage crop) per cell

# %%
def comp_damage_map (exposure_raster, impact_raster):
    
    
    return exposure_raster * impact_raster

# how will the ploting work?
